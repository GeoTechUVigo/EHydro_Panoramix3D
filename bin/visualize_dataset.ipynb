# %%
import os

os.environ["XDG_SESSION_TYPE"] = "x11"
from visualizer import Visualizer
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
visualizer = Visualizer(cfg='../config/data/s3dis_dataset.yaml', split='train')
visualizer.run()
# Out:
# Dataset Class Distribution:
#   ceiling (ID: 0): 1685260 points (18.19%)
#   floor (ID: 1): 1424838 points (15.38%)
#   wall (ID: 2): 2576923 points (27.82%)
#   beam (ID: 3): 189433 points (2.05%)
#   column (ID: 4): 189013 points (2.04%)
#   window (ID: 5): 179605 points (1.94%)
#   door (ID: 6): 554846 points (5.99%)
#   table (ID: 7): 242829 points (2.62%)
#   chair (ID: 8): 449989 points (4.86%)
#   sofa (ID: 9): 47817 points (0.52%)
#   bookcase (ID: 10): 492668 points (5.32%)
#   board (ID: 11): 120970 points (1.31%)
#   clutter (ID: 12): 1108391 points (11.97%)
# Semantic Class Distribution:
#   ceiling (ID: 0): 6576 points (14.36%)
#   floor (ID: 1): 6804 points (14.86%)
#   wall (ID: 2): 20406 points (44.57%)
#   door (ID: 6): 2255 points (4.92%)
#   clutter (ID: 12): 9746 points (21.29%)
# Semantic Class Distribution:
#   ceiling (ID: 0): 139038 points (27.53%)
#   floor (ID: 1): 119171 points (23.60%)
#   wall (ID: 2): 92123 points (18.24%)
#   column (ID: 4): 2715 points (0.54%)
#   door (ID: 6): 6767 points (1.34%)
#   chair (ID: 8): 102363 points (20.27%)
#   bookcase (ID: 10): 5288 points (1.05%)
#   board (ID: 11): 8024 points (1.59%)
#   clutter (ID: 12): 29575 points (5.86%)
